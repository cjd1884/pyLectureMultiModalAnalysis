# %%
import pickle
import pandas as pd
import sys
sys.path.insert(0,'..')
from classification import classification as cl

# %%
filename = '../data/svm_model.sav'
model = pickle.load(open(filename, 'rb'))

# %%
df = pd.read_pickle("../data/Features.pkl")

# %%
df.shape
# Out:
# (250, 171)

# %%
df.describe()
# Out:
#               0_v         1_v         2_v         3_v         4_v         5_v  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.987243    1.007779    1.003482    0.999079    1.002690    1.004887
# std      0.511366    0.515393    0.527025    0.509845    0.519520    0.527216
# min      0.336952    0.328637    0.331778    0.353690    0.331443    0.354875
# 25%      0.600874    0.613500    0.602624    0.618088    0.603582    0.605372
# 50%      0.811025    0.836122    0.821523    0.838864    0.856174    0.806832
# 75%      1.318824    1.351283    1.323077    1.306225    1.357283    1.313114
# max      2.530420    2.341366    2.504105    2.426577    2.308352    2.603424
#
#               6_v         7_v         8_v         9_v  ...        58_a  \
# count  250.000000  250.000000  250.000000  250.000000  ...  250.000000
# mean     0.998588    1.006872    1.006052    1.005731  ...    0.021903
# ...

# %%
rs = cl.standardize(df)

# %%
rs.shape
# Out:
# (250, 171)

# %%
rs.describe()
# Out:
#                 0_v           1_v           2_v           3_v           4_v  \
# count  2.500000e+02  2.500000e+02  2.500000e+02  2.500000e+02  2.500000e+02
# mean  -1.527667e-16 -4.121148e-16 -1.776357e-18  5.950795e-17  3.570477e-16
# std    1.002006e+00  1.002006e+00  1.002006e+00  1.002006e+00  1.002006e+00
# min   -1.274227e+00 -1.320359e+00 -1.277075e+00 -1.268393e+00 -1.294644e+00
# 25%   -7.570789e-01 -7.665397e-01 -7.621303e-01 -7.487674e-01 -7.697660e-01
# 50%   -3.452939e-01 -3.337281e-01 -3.459481e-01 -3.148744e-01 -2.825890e-01
# 75%    6.497221e-01  6.678264e-01  6.076297e-01  6.036391e-01  6.839068e-01
# max    3.023810e+00  2.592704e+00  2.853057e+00  2.805483e+00  2.518247e+00
#
#                 5_v         6_v           7_v           8_v           9_v  \
# count  2.500000e+02  250.000000  2.500000e+02  2.500000e+02  2.500000e+02
# mean   2.149392e-16    0.000000 -2.575717e-16  7.993606e-17 -1.207923e-16
# ...

# %%
cl.evaluate_training(rs)
# Out:
# 0.316

# %%
rs['CLASS_1'].head()
# Out:
# 0         boring
# 1    interesting
# 2         boring
# 3    interesting
# 4    interesting
# Name: CLASS_1, dtype: object

# %%
rs['CLASS_1'].head(15)
# Out:
# 0          boring
# 1     interesting
# 2          boring
# 3     interesting
# 4     interesting
# 5     interesting
# 6     interesting
# 7         neutral
# 8         neutral
# 9     interesting
# 10         boring
# 11         boring
# 12        neutral
# 13    interesting
# 14    interesting
# Name: CLASS_1, dtype: object

# %%
rs['CLASS_1'] = rs['CLASS_1'].astype('category')
cat_column = rs.select_dtypes(['category']).columns
rs[cat_column] = rs[cat_column].apply(lambda x: x.cat.codes)

# %%
rs[cat_column].head(15)
# Out:
#     CLASS_1
# 0         0
# 1         1
# 2         0
# 3         1
# 4         1
# 5         1
# 6         1
# 7         2
# 8         2
# 9         1
# 10        0
# 11        0
# 12        2
# 13        1
# 14        1

# %%
df.head()
# Out:
#        FILE     SEG      CLASS_1       0_v       1_v       2_v       3_v  \
# 0  medium_0  part_0       boring  0.972432  0.716957  0.810577  0.981358
# 1  medium_0  part_1  interesting  0.828364  0.806312  0.807211  0.852229
# 2  medium_0  part_2       boring  0.481313  0.415128  0.382306  0.450261
# 3  medium_0  part_3  interesting  0.416970  0.418615  0.363118  0.419033
# 4  medium_0  part_4  interesting  0.458658  0.348467  0.410120  0.371017
#
#         4_v       5_v       6_v  ...      58_a      59_a      60_a      61_a  \
# 0  0.865502  0.891829  0.945620  ...  0.017646  0.011899  0.012597  0.011918
# 1  0.858633  0.782054  0.859456  ...  0.021749  0.021822  0.023302  0.024560
# 2  0.430774  0.439416  0.486030  ...  0.018786  0.018780  0.012587  0.023231
# 3  0.420480  0.444704  0.427797  ...  0.017658  0.022119  0.017888  0.022534
# 4  0.433534  0.415439  0.452260  ...  0.035365  0.024567  0.018455  0.022552
#
#        62_a      63_a      64_a      65_a      66_a      67_a
# ...

# %%
new = df['CLASS_1']

# %%
new.head()
# Out:
# 0         boring
# 1    interesting
# 2         boring
# 3    interesting
# 4    interesting
# Name: CLASS_1, dtype: object

# %%
new_df = df.drop(['CLASS_1'], axis=1)

# %%
new_df.head()
# Out:
#        FILE     SEG       0_v       1_v       2_v       3_v       4_v  \
# 0  medium_0  part_0  0.972432  0.716957  0.810577  0.981358  0.865502
# 1  medium_0  part_1  0.828364  0.806312  0.807211  0.852229  0.858633
# 2  medium_0  part_2  0.481313  0.415128  0.382306  0.450261  0.430774
# 3  medium_0  part_3  0.416970  0.418615  0.363118  0.419033  0.420480
# 4  medium_0  part_4  0.458658  0.348467  0.410120  0.371017  0.433534
#
#         5_v       6_v       7_v  ...      58_a      59_a      60_a      61_a  \
# 0  0.891829  0.945620  0.798173  ...  0.017646  0.011899  0.012597  0.011918
# 1  0.782054  0.859456  0.888558  ...  0.021749  0.021822  0.023302  0.024560
# 2  0.439416  0.486030  0.383491  ...  0.018786  0.018780  0.012587  0.023231
# 3  0.444704  0.427797  0.436209  ...  0.017658  0.022119  0.017888  0.022534
# 4  0.415439  0.452260  0.449256  ...  0.035365  0.024567  0.018455  0.022552
#
#        62_a      63_a      64_a      65_a      66_a      67_a
# ...

# %%
new.to_list()
# Out:
# ['boring',
#  'interesting',
#  'boring',
#  'interesting',
#  'interesting',
#  'interesting',
#  'interesting',
#  'neutral',
#  'neutral',
#  'interesting',
#  'boring',
#  'boring',
#  'neutral',
#  'interesting',
#  'interesting',
#  'neutral',
#  'interesting',
#  'neutral',
#  'boring',
#  'boring',
#  'neutral',
#  'interesting',
#  'neutral',
#  'neutral',
#  'interesting',
#  'neutral',
#  'boring',
#  'interesting',
#  'neutral',
#  'neutral',
#  'interesting',
#  'interesting',
#  'boring',
#  'interesting',
#  'boring',
#  'boring',
#  'boring',
#  'boring',
#  'neutral',
#  'neutral',
#  'boring',
#  'interesting',
#  'boring',
#  'interesting',
#  'neutral',
#  'boring',
#  'boring',
#  'neutral',
#  'neutral',
#  'boring',
#  'interesting',
#  'boring',
#  'boring',
#  'boring',
#  'boring',
#  'boring',
#  'boring',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'interesting',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
# ...

# %%
new_df.insert (2, 'NEW_CLASS', new.tolist())

# %%
new_df.head()
# Out:
#        FILE     SEG    NEW_CLASS       0_v       1_v       2_v       3_v  \
# 0  medium_0  part_0       boring  0.972432  0.716957  0.810577  0.981358
# 1  medium_0  part_1  interesting  0.828364  0.806312  0.807211  0.852229
# 2  medium_0  part_2       boring  0.481313  0.415128  0.382306  0.450261
# 3  medium_0  part_3  interesting  0.416970  0.418615  0.363118  0.419033
# 4  medium_0  part_4  interesting  0.458658  0.348467  0.410120  0.371017
#
#         4_v       5_v       6_v  ...      58_a      59_a      60_a      61_a  \
# 0  0.865502  0.891829  0.945620  ...  0.017646  0.011899  0.012597  0.011918
# 1  0.858633  0.782054  0.859456  ...  0.021749  0.021822  0.023302  0.024560
# 2  0.430774  0.439416  0.486030  ...  0.018786  0.018780  0.012587  0.023231
# 3  0.420480  0.444704  0.427797  ...  0.017658  0.022119  0.017888  0.022534
# 4  0.433534  0.415439  0.452260  ...  0.035365  0.024567  0.018455  0.022552
#
#        62_a      63_a      64_a      65_a      66_a      67_a
# ...
